# %%
# !nvidia-smi
# Out:
# Thu Mar  9 15:17:13 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 528.02       Driver Version: 528.02       CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name            TCC/WDDM | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  NVIDIA GeForce ... WDDM  | 00000000:26:00.0  On |                  N/A |
# |  0%   43C    P8    13W / 170W |    602MiB / 12288MiB |     21%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |    0   N/A  N/A      2072    C+G   C:\Windows\explorer.exe         N/A      |
# |    0   N/A  N/A      2568    C+G   ...gram Desktop\Telegram.exe    N/A      |
# |    0   N/A  N/A      2880    C+G   ...me\Application\chrome.exe    N/A      |
# |    0   N/A  N/A      5460    C+G   ...2txyewy\TextInputHost.exe    N/A      |
# |    0   N/A  N/A      6768    C+G   ...root\Office16\WINWORD.EXE    N/A      |
# |    0   N/A  N/A      7752    C+G   ...n1h2txyewy\SearchHost.exe    N/A      |
# |    0   N/A  N/A      9024    C+G   ...v1g1gvanyjgm\WhatsApp.exe    N/A      |
# |    0   N/A  N/A     10080    C+G   ...8bbwe\WindowsTerminal.exe    N/A      |
# |    0   N/A  N/A     12648    C+G   ...587.63\msedgewebview2.exe    N/A      |
# |    0   N/A  N/A     14196    C+G   ...artMenuExperienceHost.exe    N/A      |
# |    0   N/A  N/A     15004    C+G   ...perience\NVIDIA Share.exe    N/A      |
# |    0   N/A  N/A     15152    C+G   ...cw5n1h2txyewy\LockApp.exe    N/A      |
# |    0   N/A  N/A     16180    C+G   ...e\PhoneExperienceHost.exe    N/A      |
# +-----------------------------------------------------------------------------+

# %%
import matplotlib.pyplot as plt
import seaborn as sns

import keras
from keras.models import Sequential
from keras.layers import Dense, Conv2D , MaxPool2D , Flatten , Dropout 
from keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import Adam

from sklearn.metrics import classification_report,confusion_matrix

import tensorflow as tf

import cv2
import os

import numpy as np

# %%
labels = ["0","1","2","3","4"]
img_size = 32
def get_data(data_dir):
    data = [] 
    for label in labels: 
        path = os.path.join(data_dir, label)
        class_num = labels.index(label)
        for img in os.listdir(path):
            try:
                img_arr = cv2.imread(os.path.join(path, img))[...,::-1] #convert BGR to RGB format
                resized_arr = cv2.resize(img_arr, (img_size, img_size)) # Reshaping images to preferred size
                data.append([resized_arr, class_num])
            except Exception as e:
                print(e)
    return np.array(data)

# %%
train = get_data(r"C:\Users\USER\Downloads\Compressed\augmentation balenced new\augmentation balenced new")
# Out:
# 'NoneType' object is not subscriptable
# C:\Users\USER\AppData\Local\Temp\ipykernel_16388\3965805998.py:15: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   return np.array(data)

# %%
# l = []
# for i in train:
#     if(i[1] == 0):
#         l.append("0")
#     elif(i[1] == 1):
#           l.append("1")
#     elif(i[1] == 2):
#           l.append("2")
#     elif(i[1] == 3):
#           l.append("3")
#     elif(i[1] == 4):
#           l.append("4")
            
       
# sns.set_style('darkgrid')
# sns.countplot(l)

# %%
plt.figure(figsize = (5,5))
plt.imshow(train[1][0])
plt.title(labels[train[0][1]])
# Out:
# Text(0.5, 1.0, '0')

# %%
x_train = []
y_train = []


for feature, label in train:
  x_train.append(feature)
  y_train.append(label)
x_train = np.array(x_train) / 255
x_train.reshape(-1, img_size, img_size, 1)
y_train = np.array(y_train)

# %%
# split with a stratified sampling
from sklearn.model_selection import train_test_split
(x_train, x_test, y_train, y_test) = train_test_split(x_train, y_train,
    test_size=0.15, stratify=y_train, random_state=42)

# %%
# !pip install -U -q tensorflow-addons

# %%
from tensorflow.keras import layers
from tensorflow import keras

import matplotlib.pyplot as plt
import tensorflow_addons as tfa
import tensorflow as tf
import numpy as np

# %%
y_train = keras.utils.to_categorical(
    y_train, num_classes=5, dtype='float32'
)
y_test = keras.utils.to_categorical(
    y_test, num_classes=5, dtype='float32'
)

# %%
positional_emb = True
conv_layers = 2
projection_dim = 128

num_heads = 2
transformer_units = [
    projection_dim,
    projection_dim,
]
transformer_layers = 1
stochastic_depth_rate = 0.1

learning_rate = 0.001
weight_decay = 0.0001
batch_size = 128
num_epochs = 200
image_size = 32

# %%
num_classes = 5
input_shape = (32, 32, 3)

# %%
print(f"x_train shape: {x_train.shape} - y_train shape: {y_train.shape}")
print(f"x_test shape: {x_test.shape} - y_test shape: {y_test.shape}")
# Out:
# x_train shape: (131648, 32, 32, 3) - y_train shape: (131648, 5)
# x_test shape: (23233, 32, 32, 3) - y_test shape: (23233, 5)

# %%
class CCTTokenizer(layers.Layer):
    def __init__(
        self,
        kernel_size=3,
        stride=1,
        padding=1,
        pooling_kernel_size=3,
        pooling_stride=2,
        num_conv_layers=conv_layers,
        num_output_channels=[64, 128],
        positional_emb=positional_emb,
        **kwargs,
    ):
        super(CCTTokenizer, self).__init__(**kwargs)

        # This is our tokenizer.
        self.conv_model = keras.Sequential()
        for i in range(num_conv_layers):
            self.conv_model.add(
                layers.Conv2D(
                    num_output_channels[i],
                    kernel_size,
                    stride,
                    padding="valid",
                    use_bias=False,
                    activation="relu",
                    kernel_initializer="he_normal",
                )
            )
            self.conv_model.add(layers.ZeroPadding2D(padding))
            self.conv_model.add(
                layers.MaxPool2D(pooling_kernel_size, pooling_stride, "same")
            )

        self.positional_emb = positional_emb

    def call(self, images):
        outputs = self.conv_model(images)
        # After passing the images through our mini-network the spatial dimensions
        # are flattened to form sequences.
        reshaped = tf.reshape(
            outputs,
            (-1, tf.shape(outputs)[1] * tf.shape(outputs)[2], tf.shape(outputs)[-1]),
        )
        return reshaped

    def positional_embedding(self, image_size):
        # Positional embeddings are optional in CCT. Here, we calculate
        # the number of sequences and initialize an `Embedding` layer to
        # compute the positional embeddings later.
        if self.positional_emb:
            dummy_inputs = tf.ones((1, image_size, image_size, 3))
            dummy_outputs = self.call(dummy_inputs)
            sequence_length = tf.shape(dummy_outputs)[1]
            projection_dim = tf.shape(dummy_outputs)[-1]

            embed_layer = layers.Embedding(
                input_dim=sequence_length, output_dim=projection_dim
            )
            return embed_layer, sequence_length
        else:
            return None

# %%
# Referred from: github.com:rwightman/pytorch-image-models.
class StochasticDepth(layers.Layer):
    def __init__(self, drop_prop, **kwargs):
        super(StochasticDepth, self).__init__(**kwargs)
        self.drop_prob = drop_prop

    def call(self, x, training=None):
        if training:
            keep_prob = 1 - self.drop_prob
            shape = (tf.shape(x)[0],) + (1,) * (len(tf.shape(x)) - 1)
            random_tensor = keep_prob + tf.random.uniform(shape, 0, 1)
            random_tensor = tf.floor(random_tensor)
            return (x / keep_prob) * random_tensor
        return x

# %%
def mlp(x, hidden_units, dropout_rate):
    for units in hidden_units:
        x = layers.Dense(units, activation=tf.nn.gelu)(x)
        x = layers.Dropout(dropout_rate)(x)
    return x

# %%
# Note the rescaling layer. These layers have pre-defined inference behavior.
data_augmentation = keras.Sequential(
    [
        layers.Rescaling(scale=1.0 / 255),
        layers.RandomCrop(image_size, image_size),
        layers.RandomFlip("horizontal"),
    ],
    name="data_augmentation",
)

# %%
def create_cct_model(
    image_size=image_size,
    input_shape=input_shape,
    num_heads=num_heads,
    projection_dim=projection_dim,
    transformer_units=transformer_units,
):

    inputs = layers.Input(input_shape)

    # Augment data.
    augmented = data_augmentation(inputs)

    # Encode patches.
    cct_tokenizer = CCTTokenizer()
    encoded_patches = cct_tokenizer(augmented)

    # Apply positional embedding.
    if positional_emb:
        pos_embed, seq_length = cct_tokenizer.positional_embedding(image_size)
        positions = tf.range(start=0, limit=seq_length, delta=1)
        position_embeddings = pos_embed(positions)
        encoded_patches += position_embeddings

    # Calculate Stochastic Depth probabilities.
    dpr = [x for x in np.linspace(0, stochastic_depth_rate, transformer_layers)]

    # Create multiple layers of the Transformer block.
    for i in range(transformer_layers):
        # Layer normalization 1.
        x1 = layers.LayerNormalization(epsilon=1e-5)(encoded_patches)

        # Create a multi-head attention layer.
        attention_output = layers.MultiHeadAttention(
            num_heads=num_heads, key_dim=projection_dim, dropout=0.1
        )(x1, x1)

        # Skip connection 1.
        attention_output = StochasticDepth(dpr[i])(attention_output)
        x2 = layers.Add()([attention_output, encoded_patches])

        # Layer normalization 2.
        x3 = layers.LayerNormalization(epsilon=1e-5)(x2)

        # MLP.
        x3 = mlp(x3, hidden_units=transformer_units, dropout_rate=0.1)

        # Skip connection 2.
        x3 = StochasticDepth(dpr[i])(x3)
        encoded_patches = layers.Add()([x3, x2])

    # Apply sequence pooling.
    representation = layers.LayerNormalization(epsilon=1e-5)(encoded_patches)
    attention_weights = tf.nn.softmax(layers.Dense(1)(representation), axis=1)
    weighted_representation = tf.matmul(
        attention_weights, representation, transpose_a=True
    )
    weighted_representation = tf.squeeze(weighted_representation, -2)

    # Classify outputs.
    logits = layers.Dense(num_classes)(weighted_representation)
    # Create the Keras model.
    model = keras.Model(inputs=inputs, outputs=logits)
    model.summary()
    return model

# %%
def run_experiment(model):
    optimizer = tf.keras.optimizers.Adam(
    learning_rate=0.001,
    beta_1=0.9,
    beta_2=0.999,
    epsilon=1e-07,
    amsgrad=False,
    name="Adam"
)

    model.compile(
        optimizer=optimizer,
        loss=keras.losses.CategoricalCrossentropy(
            from_logits=True, label_smoothing=0.1
        ),
        metrics=[
            keras.metrics.CategoricalAccuracy(name="accuracy"),
            keras.metrics.TopKCategoricalAccuracy(5, name="top-5-accuracy"),
        ],
    )

    checkpoint_filepath = r"D:\Visual Disorders\Weights\cctmodelNEWdataset 32.h5"
    checkpoint_callback = keras.callbacks.ModelCheckpoint(
        checkpoint_filepath,
        monitor="val_accuracy",
        save_best_only=True,
        save_weights_only=True,
    )

    history = model.fit(
        x=x_train,
        y=y_train,
        batch_size=batch_size,
        epochs=num_epochs,
        validation_split=0.10,
        callbacks=[checkpoint_callback],
    )

    model.load_weights(checkpoint_filepath)
    _, accuracy, top_5_accuracy = model.evaluate(x_test, y_test)
    print(f"Test accuracy: {round(accuracy * 100, 2)}%")
    print(f"Test top 5 accuracy: {round(top_5_accuracy * 100, 2)}%")
    from sklearn.metrics import classification_report, confusion_matrix



    # as I've trained my model on MNIST as odd or even (binary classes)
    target_names = ["0", "1", "2","3","4"]


    # get predict prob and label 
    ypred = model.predict(x_test, verbose=1)
    ypred = np.argmax(ypred, axis=1)
    print(classification_report(np.argmax(y_test, axis=1), ypred, target_names=target_names))
    import matplotlib.pyplot as plt
    import seaborn as sns
    import pandas as pd 

    cm = confusion_matrix(np.argmax(y_test, axis=1), ypred)
    cm = pd.DataFrame(cm, range(5),range(5))
    plt.figure(figsize = (10,10))

    sns.heatmap(cm, annot=True, annot_kws={"size": 12}) # font size
    plt.show()
    return history


cct_model = create_cct_model()
history = run_experiment(cct_model)
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 32, 32, 3)]  0           []
#
#  data_augmentation (Sequential)  (None, 32, 32, 3)   0           ['input_1[0][0]']
#
#  cct_tokenizer (CCTTokenizer)   (None, 64, 128)      75456       ['data_augmentation[0][0]']
#
#  tf.__operators__.add (TFOpLamb  (None, 64, 128)     0           ['cct_tokenizer[0][0]']
#  da)
#
#  layer_normalization (LayerNorm  (None, 64, 128)     256         ['tf.__operators__.add[0][0]']
#  alization)
#
#  multi_head_attention (MultiHea  (None, 64, 128)     131968      ['layer_normalization[0][0]',
#  dAttention)                                                      'layer_normalization[0][0]']
#
#  stochastic_depth (StochasticDe  (None, 64, 128)     0           ['multi_head_attention[0][0]']
#  pth)
#
#  add (Add)                      (None, 64, 128)      0           ['stochastic_depth[0][0]',
#                                                                   'tf.__operators__.add[0][0]']
#
#  layer_normalization_1 (LayerNo  (None, 64, 128)     256         ['add[0][0]']
#  rmalization)
#
#  dense (Dense)                  (None, 64, 128)      16512       ['layer_normalization_1[0][0]']
#
#  dropout (Dropout)              (None, 64, 128)      0           ['dense[0][0]']
#
#  dense_1 (Dense)                (None, 64, 128)      16512       ['dropout[0][0]']
#
#  dropout_1 (Dropout)            (None, 64, 128)      0           ['dense_1[0][0]']
#
#  stochastic_depth_1 (Stochastic  (None, 64, 128)     0           ['dropout_1[0][0]']
#  Depth)
#
#  add_1 (Add)                    (None, 64, 128)      0           ['stochastic_depth_1[0][0]',
#                                                                   'add[0][0]']
#
#  layer_normalization_2 (LayerNo  (None, 64, 128)     256         ['add_1[0][0]']
#  rmalization)
#
#  dense_2 (Dense)                (None, 64, 1)        129         ['layer_normalization_2[0][0]']
#
#  tf.nn.softmax (TFOpLambda)     (None, 64, 1)        0           ['dense_2[0][0]']
#
#  tf.linalg.matmul (TFOpLambda)  (None, 1, 128)       0           ['tf.nn.softmax[0][0]',
#                                                                   'layer_normalization_2[0][0]']
#
#  tf.compat.v1.squeeze (TFOpLamb  (None, 128)         0           ['tf.linalg.matmul[0][0]']
#  da)
#
#  dense_3 (Dense)                (None, 5)            645         ['tf.compat.v1.squeeze[0][0]']
#
# ==================================================================================================
# Total params: 241,990
# Trainable params: 241,990
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Epoch 1/200
# 926/926 [==============================] - 65s 68ms/step - loss: 1.4842 - accuracy: 0.3839 - top-5-accuracy: 1.0000 - val_loss: 1.4344 - val_accuracy: 0.4131 - val_top-5-accuracy: 1.0000
# Epoch 2/200
# 926/926 [==============================] - 61s 66ms/step - loss: 1.3848 - accuracy: 0.4473 - top-5-accuracy: 1.0000 - val_loss: 1.3338 - val_accuracy: 0.4857 - val_top-5-accuracy: 1.0000
200
# 926/926 [==============================] - 58s 63ms/step - loss: 0.5152 - accuracy: 0.9698 - top-5-accuracy: 1.0000 - val_loss: 0.6252 - val_accuracy: 0.9298 - val_top-5-accuracy: 1.0000
# Epoch 189/200
# 926/926 [==============================] - 58s 63ms/step - loss: 0.5145 - accuracy: 0.9702 - top-5-accuracy: 1.0000 - val_loss: 0.6469 - val_accuracy: 0.9193 - val_top-5-accuracy: 1.0000
# Epoch 190/200
# 926/926 [==============================] - 57s 62ms/step - loss: 0.5147 - accuracy: 0.9699 - top-5-accuracy: 1.0000 - val_loss: 0.6109 - val_accuracy: 0.9352 - val_top-5-accuracy: 1.0000
# Epoch 191/200
# 926/926 [==============================] - 60s 65ms/step - loss: 0.5136 - accuracy: 0.9713 - top-5-accuracy: 1.0000 - val_loss: 0.6153 - val_accuracy: 0.9351 - val_top-5-accuracy: 1.0000
# Epoch 192/200
# 926/926 [==============================] - 58s 63ms/step - loss: 0.5135 - accuracy: 0.9698 - top-5-accuracy: 1.0000 - val_loss: 0.6147 - val_accuracy: 0.9357 - val_top-5-accuracy: 1.0000
# Epoch 193/200
# 926/926 [==============================] - 58s 63ms/step - loss: 0.5117 - accuracy: 0.9712 - top-5-accuracy: 1.0000 - val_loss: 0.6136 - val_accuracy: 0.9336 - val_top-5-accuracy: 1.0000
# Epoch 194/200
# 926/926 [==============================] - 59s 64ms/step - loss: 0.5104 - accuracy: 0.9721 - top-5-accuracy: 1.0000 - val_loss: 0.6183 - val_accuracy: 0.9344 - val_top-5-accuracy: 1.0000
# Epoch 195/200
# 926/926 [==============================] - 59s 64ms/step - loss: 0.5121 - accuracy: 0.9710 - top-5-accuracy: 1.0000 - val_loss: 0.6344 - val_accuracy: 0.9270 - val_top-5-accuracy: 1.0000
# Epoch 196/200
# 926/926 [==============================] - 58s 63ms/step - loss: 0.5126 - accuracy: 0.9709 - top-5-accuracy: 1.0000 - val_loss: 0.6277 - val_accuracy: 0.9262 - val_top-5-accuracy: 1.0000
# Epoch 197/200
# 926/926 [==============================] - 59s 64ms/step - loss: 0.5079 - accuracy: 0.9745 - top-5-accuracy: 1.0000 - val_loss: 0.6149 - val_accuracy: 0.9362 - val_top-5-accuracy: 1.0000
# Epoch 198/200
# 926/926 [==============================] - 57s 61ms/step - loss: 0.5115 - accuracy: 0.9717 - top-5-accuracy: 1.0000 - val_loss: 0.6043 - val_accuracy: 0.9414 - val_top-5-accuracy: 1.0000
# Epoch 199/200
# 926/926 [==============================] - 59s 64ms/step - loss: 0.5074 - accuracy: 0.9741 - top-5-accuracy: 1.0000 - val_loss: 0.6405 - val_accuracy: 0.9206 - val_top-5-accuracy: 1.0000
# Epoch 200/200
# 926/926 [==============================] - 57s 62ms/step - loss: 0.5108 - accuracy: 0.9714 - top-5-accuracy: 1.0000 - val_loss: 0.6224 - val_accuracy: 0.9297 - val_top-5-accuracy: 1.0000
# 727/727 [==============================] - 3s 4ms/step - loss: 0.6070 - accuracy: 0.9365 - top-5-accuracy: 1.0000
# Test accuracy: 93.65%
# Test top 5 accuracy: 100.0%
# 727/727 [==============================] - 3s 3ms/step
#               precision    recall  f1-score   support
#
#            0       0.94      0.94      0.94      4649
#            1       0.94      0.94      0.94      7250
#            2       0.93      0.93      0.93      4649
#            3       0.92      0.91      0.91      2810
#            4       0.95      0.95      0.95      3875
#
#     accuracy                           0.94     23233
#    macro avg       0.93      0.93      0.93     23233
# weighted avg       0.94      0.94      0.94     23233

# %%
plt.plot(history.history["loss"], label="train_loss")
plt.plot(history.history["val_loss"], label="val_loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.title("Train and Validation Losses Over Epochs", fontsize=14)
plt.legend()
plt.grid()
plt.show()

# %%
plt.plot(history.history["loss"], label="train_loss")
plt.plot(history.history["val_loss"], label="val_loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.title("Train and Validation Losses Over Epochs", fontsize=14)
plt.legend()
plt.grid()
plt.show()
